# %% [markdown]
# # Java Plagiarism Detector

# %% [markdown]
# Import Lexer analyzer and source code to analyze

# %%
from java_lexer import Lexer
from source_codes import SOURCE_CODE2
# Out:
# import java.util.ArrayList;
# import java.util.List;
#
# // This is a single-line comment
# class HelloWorld {
#     public static void main(String[] args) {
#         /* This is a
#            multi-line comment */
#         boolean flag = true;
#         String message = "Hello, World!";
#         int number = 123;
#         double pi = 3.14;
#         int[] array = {1, 2, 3};
#         if (flag == true) {
#             System.out.println(message);
#         }
#         else {
#             System.out.println("Flag is false.");
#         }
#     }
# }
#
#
# IMPORT: import java.util.ArrayList;
# IMPORT: import java.util.List;
# COMMENT_SINGLE: // This is a single-line comment
# KEYWORD: class
# IDENTIFIER: HelloWorld
# PUNCTUATION: {
# KEYWORD: public
# KEYWORD: static
# DATA_TYPE: void
# IDENTIFIER: main
# PUNCTUATION: (
# IDENTIFIER: String
# PUNCTUATION: [
# PUNCTUATION: ]
# IDENTIFIER: args
# PUNCTUATION: )
# PUNCTUATION: {
# COMMENT_MULTI: /* This is a
#            multi-line comment */
# DATA_TYPE: boolean
# IDENTIFIER: flag
# OPERATOR: =
# BOOLEAN: true
# PUNCTUATION: ;
# IDENTIFIER: String
# IDENTIFIER: message
# OPERATOR: =
# STRING: "Hello, World!"
# PUNCTUATION: ;
# DATA_TYPE: int
# IDENTIFIER: number
# OPERATOR: =
# NUMBER: 123
# PUNCTUATION: ;
# DATA_TYPE: double
# IDENTIFIER: pi
# OPERATOR: =
# NUMBER: 3.14
# PUNCTUATION: ;
# DATA_TYPE: int
# PUNCTUATION: [
# PUNCTUATION: ]
# IDENTIFIER: array
# OPERATOR: =
# PUNCTUATION: {
# NUMBER: 1
# PUNCTUATION: ,
# NUMBER: 2
# PUNCTUATION: ,
# NUMBER: 3
# PUNCTUATION: }
# PUNCTUATION: ;
# KEYWORD: if
# PUNCTUATION: (
# IDENTIFIER: flag
# OPERATOR: =
# OPERATOR: =
# BOOLEAN: true
# PUNCTUATION: )
# PUNCTUATION: {
# SYSTEM_CALL: System.out.println
# PUNCTUATION: (
# IDENTIFIER: message
# PUNCTUATION: )
# PUNCTUATION: ;
# PUNCTUATION: }
# KEYWORD: else
# PUNCTUATION: {
# SYSTEM_CALL: System.out.println
# PUNCTUATION: (
# STRING: "Flag is false."
# PUNCTUATION: )
# PUNCTUATION: ;
# PUNCTUATION: }
# PUNCTUATION: }
# PUNCTUATION: }

# %% [markdown]
# Call Lexer class and obtain all tokens from source code

# %%
lexer = Lexer(SOURCE_CODE2)
tokens = lexer.tokenize()

# %% [markdown]
# Print the identified tokens

# %%
for token in tokens:
    print(token.type + ':', token.value)
# Out:
# COMMENT_SINGLE: // Definición de la clase del nodo del árbol
# KEYWORD: class
# IDENTIFIER: TreeNode
# PUNCTUATION: {
# DATA_TYPE: int
# IDENTIFIER: val
# PUNCTUATION: ;
# IDENTIFIER: TreeNode
# IDENTIFIER: left
# PUNCTUATION: ;
# IDENTIFIER: TreeNode
# IDENTIFIER: right
# PUNCTUATION: ;
# IDENTIFIER: TreeNode
# PUNCTUATION: (
# DATA_TYPE: int
# IDENTIFIER: val
# PUNCTUATION: )
# PUNCTUATION: {
# KEYWORD: this
# PUNCTUATION: .
# IDENTIFIER: val
# OPERATOR: =
# IDENTIFIER: val
# PUNCTUATION: ;
# PUNCTUATION: }
# PUNCTUATION: }
# COMMENT_SINGLE: // Clase principal con la función de recorrido del árbol
# KEYWORD: class
# IDENTIFIER: TreeTraversal
# PUNCTUATION: {
# COMMENT_SINGLE: // Función de recorrido en profundidad primero (DFS)
# KEYWORD: public
# KEYWORD: static
# DATA_TYPE: void
# IDENTIFIER: DFS
# PUNCTUATION: (
# IDENTIFIER: TreeNode
# IDENTIFIER: root
# PUNCTUATION: )
# PUNCTUATION: {
# KEYWORD: if
# PUNCTUATION: (
# IDENTIFIER: root
# OPERATOR: =
# OPERATOR: =
# NULL: null
# PUNCTUATION: )
# PUNCTUATION: {
# KEYWORD: return
# PUNCTUATION: ;
# PUNCTUATION: }
# COMMENT_SINGLE: // Imprimir el valor del nodo actual
# SYSTEM_CALL: System.out.print
# PUNCTUATION: (
# IDENTIFIER: root
# PUNCTUATION: .
# IDENTIFIER: val
# OPERATOR: +
# STRING: " "
# PUNCTUATION: )
# PUNCTUATION: ;
# COMMENT_SINGLE: // Recorrer el subárbol izquierdo
# IDENTIFIER: DFS
# PUNCTUATION: (
# IDENTIFIER: root
# PUNCTUATION: .
# IDENTIFIER: left
# PUNCTUATION: )
# PUNCTUATION: ;
# COMMENT_SINGLE: // Recorrer el subárbol derecho
# IDENTIFIER: DFS
# PUNCTUATION: (
# IDENTIFIER: root
# PUNCTUATION: .
# IDENTIFIER: right
# PUNCTUATION: )
# PUNCTUATION: ;
# PUNCTUATION: }
# COMMENT_SINGLE: // Función principal para probar el recorrido del árbol
# KEYWORD: public
# KEYWORD: static
# DATA_TYPE: void
# IDENTIFIER: main
# PUNCTUATION: (
# IDENTIFIER: String
# PUNCTUATION: [
# PUNCTUATION: ]
# IDENTIFIER: args
# PUNCTUATION: )
# PUNCTUATION: {
# COMMENT_SINGLE: // Crear el árbol de ejemplo
# IDENTIFIER: TreeNode
# IDENTIFIER: root
# OPERATOR: =
# KEYWORD: new
# IDENTIFIER: TreeNode
# PUNCTUATION: (
# NUMBER: 1
# PUNCTUATION: )
# PUNCTUATION: ;
# IDENTIFIER: root
# PUNCTUATION: .
# IDENTIFIER: left
# OPERATOR: =
# KEYWORD: new
# IDENTIFIER: TreeNode
# PUNCTUATION: (
# NUMBER: 2
# PUNCTUATION: )
# PUNCTUATION: ;
# IDENTIFIER: root
# PUNCTUATION: .
# IDENTIFIER: right
# OPERATOR: =
# KEYWORD: new
# IDENTIFIER: TreeNode
# PUNCTUATION: (
# NUMBER: 3
# PUNCTUATION: )
# PUNCTUATION: ;
# IDENTIFIER: root
# PUNCTUATION: .
# IDENTIFIER: left
# PUNCTUATION: .
# IDENTIFIER: left
# OPERATOR: =
# KEYWORD: new
# IDENTIFIER: TreeNode
# PUNCTUATION: (
# NUMBER: 4
# PUNCTUATION: )
# PUNCTUATION: ;
# IDENTIFIER: root
# PUNCTUATION: .
# IDENTIFIER: left
# PUNCTUATION: .
# IDENTIFIER: right
# OPERATOR: =
# KEYWORD: new
# IDENTIFIER: TreeNode
# PUNCTUATION: (
# NUMBER: 5
# PUNCTUATION: )
# PUNCTUATION: ;
# COMMENT_SINGLE: // Realizar el recorrido en profundidad primero (DFS)
# SYSTEM_CALL: System.out.println
# PUNCTUATION: (
# STRING: "Recorrido en profundidad primero (DFS):"
# PUNCTUATION: )
# PUNCTUATION: ;
# IDENTIFIER: DFS
# PUNCTUATION: (
# IDENTIFIER: root
# PUNCTUATION: )
# PUNCTUATION: ;
# PUNCTUATION: }
# PUNCTUATION: }
